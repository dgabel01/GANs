# %% [markdown]
# ## **Nvidia StyleGAN2**

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# %cd stylegan2-ada-pytorch
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 131 (delta 0), reused 0 (delta 0), pack-reused 129 (from 2)
# Receiving objects: 100% (131/131), 1.13 MiB | 26.31 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# /content/stylegan/stylegan2-ada-pytorch

# %%
# !mkdir pretrained
# !wget -O pretrained/ffhq.pkl https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Out:
# --2025-05-03 09:30:12--  https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl
# Resolving nvlabs-fi-cdn.nvidia.com (nvlabs-fi-cdn.nvidia.com)... 3.165.75.59, 3.165.75.21, 3.165.75.119, ...
# Connecting to nvlabs-fi-cdn.nvidia.com (nvlabs-fi-cdn.nvidia.com)|3.165.75.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381624121 (364M) [binary/octet-stream]
# Saving to: ‘pretrained/ffhq.pkl’
#
# pretrained/ffhq.pkl 100%[===================>] 363.94M   164MB/s    in 2.2s
#
# 2025-05-03 09:30:15 (164 MB/s) - ‘pretrained/ffhq.pkl’ saved [381624121/381624121]

# %%
# !python generate.py \
  --outdir=out \
  --trunc=0.7 \
  --seeds=100-109 \
  --network=pretrained/ffhq.pkl
# Out:
# Loading networks from "pretrained/ffhq.pkl"...
# Generating image for seed 100 (0/10) ...
# Setting up PyTorch plugin "bias_act_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/bias_act.py:50: UserWarning: Failed to build CUDA kernels for bias_act. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/bias_act.py", line 48, in _init
#     _plugin = custom_ops.get_plugin('bias_act_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1798, in _jit_compile
#     _write_ninja_file_and_build_library(
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1888, in _write_ninja_file_and_build_library
#     verify_ninja_availability()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1945, in verify_ninja_availability
#     raise RuntimeError("Ninja is required to load C++ extensions")
# RuntimeError: Ninja is required to load C++ extensions
#
#   warnings.warn('Failed to build CUDA kernels for bias_act. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1798, in _jit_compile
#     _write_ninja_file_and_build_library(
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1888, in _write_ninja_file_and_build_library
#     verify_ninja_availability()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1945, in verify_ninja_availability
#     raise RuntimeError("Ninja is required to load C++ extensions")
# RuntimeError: Ninja is required to load C++ extensions
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Generating image for seed 101 (1/10) ...
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
# ...
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())
# Setting up PyTorch plugin "upfirdn2d_plugin"... Failed!
# /content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py:34: UserWarning: Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:
#
# Traceback (most recent call last):
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/ops/upfirdn2d.py", line 32, in _init
#     _plugin = custom_ops.get_plugin('upfirdn2d_plugin', sources=sources, extra_cuda_cflags=['--use_fast_math'])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/stylegan/stylegan2-ada-pytorch/torch_utils/custom_ops.py", line 110, in get_plugin
#     torch.utils.cpp_extension.load(name=module_name, verbose=verbose_build, sources=sources, **build_kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1380, in load
#     return _jit_compile(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 1823, in _jit_compile
#     return _import_module_from_library(name, build_directory, is_python_module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py", line 2245, in _import_module_from_library
#     module = importlib.util.module_from_spec(spec)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 573, in module_from_spec
#   File "<frozen importlib._bootstrap_external>", line 1233, in create_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
# ImportError: /root/.cache/torch_extensions/py311_cu124/upfirdn2d_plugin/upfirdn2d_plugin.so: cannot open shared object file: No such file or directory
#
#   warnings.warn('Failed to build CUDA kernels for upfirdn2d. Falling back to slow reference implementation. Details:\n\n' + traceback.format_exc())

# %%
import zipfile
import glob
from google.colab import files

# Zip the output images
zipf = zipfile.ZipFile('generated_images3.zip', 'w')
for file in glob.glob("out/*.png"):
    zipf.write(file)
zipf.close()

# Download the zip file
files.download('generated_images3.zip')
